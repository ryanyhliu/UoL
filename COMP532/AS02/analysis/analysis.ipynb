# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read data from CSV file
data = pd.read_csv('data.csv', sep=' ',header=None)

data.head()

# # 删除前4行
# data = data.drop([0, 1, 2, 3])

# # 删除所有 "模型状态字典已保存至 c:\Users\isrya\#MyFiles\#MyCode\GithubUoL\COMP532\AS02\models\model_0.pth" 的行
# data = data[data[0] != '模型状态字典已保存至']

# 示例数据:
# 0	Episode:	0/5000,	score:	109,	cumulative	reward:	-213.437076
# 1	Episode:	1/5000,	score:	90,	cumulative	reward:	-79.263939
# 2	Episode:	2/5000,	score:	104,	cumulative	reward:	-216.793605
# 3	Episode:	3/5000,	score:	116,	cumulative	reward:	-109.726400
# 4	Episode:	4/5000,	score:	96,	cumulative	reward:	-130.167873
# 根据index和第六列绘制折线图
plt.plot(data.index, data[6])

# plt.plot(data.index[-500:], data[6][-500:])
