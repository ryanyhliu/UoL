# %%
import numpy as np

A = np.array([[337,527], [-1,1]])

print("The pass code is:", int(np.linalg.det(A)))
# Out:
# The pass code is: 863

# %%
import matplotlib.pyplot as plt
import numpy as np

# 定义t的取值范围
t = np.linspace(-2, 2, 400)

# 定义铰链损失函数h(t)
h_t = np.maximum(0, t)

# 绘制图像
plt.figure(figsize=(8, 6))
# 颜色设置为红色, 宽度设置为4, 添加标签
plt.plot(t, h_t, color='red', linewidth=4, label='h(t) = max(0, t)')
# 格子设置为正方形
plt.axis('square')
plt.xlabel('t')
plt.ylabel('h(t)')
plt.title('Hinge Loss Function')
plt.legend()

# 显示x轴
plt.axhline(0, color='black', linewidth=2)
# 显示y轴
plt.axvline(0, color='black', linewidth=2)


plt.grid(True)
plt.show()
